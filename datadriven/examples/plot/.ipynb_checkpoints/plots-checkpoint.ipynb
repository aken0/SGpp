# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
from scipy.integrate import nquad
# %matplotlib inline

# %%
def printer(name):
    base=np.genfromtxt(name+"(base-level5).txt",delimiter=',')
    ee=np.genfromtxt(name+"(e-level5).txt",delimiter=',')
    ef=np.genfromtxt(name+"(f-level5).txt",delimiter=',')
    eg=np.genfromtxt(name+"(g-level5).txt",delimiter=',')
    baserows=base.view([('',base.dtype)]*base.shape[1])
    eerows=ee.view([('',ee.dtype)]*ee.shape[1])
    efrows=ef.view([('',ef.dtype)]*ef.shape[1])
    egrows=eg.view([('',eg.dtype)]*eg.shape[1])
    eedif=np.setdiff1d(eerows,baserows).view(ee.dtype).reshape(-1,ee.shape[1])
    efdif=np.setdiff1d(efrows,baserows).view(ef.dtype).reshape(-1,ef.shape[1])
    egdif=np.setdiff1d(egrows,baserows).view(eg.dtype).reshape(-1,eg.shape[1])
    plt.figure(figsize=(5,5),dpi=300)
    plt.plot(base[:,0],base[:,1],".b")
    plt.plot(eedif[:,0],eedif[:,1],".r")

    plt.figure(figsize=(5,5),dpi=300)
    plt.plot(base[:,0],base[:,1],".b")
    plt.plot(efdif[:,0],efdif[:,1],".r")
    plt.figure(figsize=(5,5),dpi=300)
    plt.plot(base[:,0],base[:,1],".b")
    plt.plot(egdif[:,0],egdif[:,1],".r")
    df=pd.read_csv(name+".txt",header=None)
    ye=nquad(lambda x,y: (x**3-y**2),[[-1,1],[-1,1]])
    ye2=nquad(lambda x,y:1+(np.sin(x)+np.cos(y))/np.exp(y),[[-1,1],[-1,1]])
    plt.figure(figsize=(7,5),dpi=200)
    plt.gca().set_yscale('log')
    plt.xlabel('level')
    plt.plot(range(2,df.shape[1]+2),abs(df.loc[1]-4),label='1.0')
    plt.plot(range(2,df.shape[1]+2),abs(df.loc[0]-ye[0]),label='x^3-x^2')
    plt.plot(range(2,df.shape[1]+2),abs(df.loc[2]-ye2[0]),label='1+(sin(x)+cos(x))/e^x')
    plt.legend()
    plt.savefig("regular.png")
    plt.show()
    plt.figure(figsize=(7,5),dpi=200)
    plt.gca().set_yscale('log')
    plt.xlabel('level')
    plt.plot(range(2,df.shape[1]+2),abs(df.loc[4]),label='1.0')
    plt.plot(range(2,df.shape[1]+2),abs(df.loc[3]),label='x^3-x^2')
    plt.plot(range(2,df.shape[1]+2),abs(df.loc[5]),label='1+(sin(x)+cos(x))/e^x')
    plt.legend()
    plt.savefig("regular.png")
    plt.show()

# %%
printer("LinearBoundary")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-cd728b5a69f1> in <module>
# ----> 1 printer("LinearBoundary")
#
# <ipython-input-88-a5269d06366c> in printer(name)
#      25     ye2=nquad(lambda x,y:1+(np.sin(x)+np.cos(y))/np.exp(y),[[-1,1],[-1,1]])
#      26     plt.figure(figsize=(7,5),dpi=200)
# ---> 27     plt.gca().set_yscale('log',nonposx='clip')
#      28     plt.xlabel('level')
#      29     plt.plot(range(2,df.shape[1]+2),abs(df.loc[1]-4),label='1.0')
#
# /usr/lib/python3.8/site-packages/matplotlib/axes/_base.py in set_yscale(self, value, **kwargs)
#    3708         g = self.get_shared_y_axes()
#    3709         for ax in g.get_siblings(self):
# -> 3710             ax.yaxis._set_scale(value, **kwargs)
#    3711             ax._update_transScale()
#    3712             ax.stale = True
#
# /usr/lib/python3.8/site-packages/matplotlib/axis.py in _set_scale(self, value, **kwargs)
#     797
#     798     def _set_scale(self, value, **kwargs):
# --> 799         self._scale = mscale.scale_factory(value, self, **kwargs)
#     800         self._scale.set_default_locators_and_formatters(self)
#     801
#
# /usr/lib/python3.8/site-packages/matplotlib/scale.py in scale_factory(scale, axis, **kwargs)
#     731     if scale not in _scale_mapping:
#     732         raise ValueError("Unknown scale type '%s'" % scale)
# --> 733     return _scale_mapping[scale](axis, **kwargs)
#     734
#     735 if scale_factory.__doc__:
#
# TypeError: 'LogScale' object is not callable

# %%
df=pd.read_csv('regular.txt',header=None)
plt.figure(figsize=(7,5),dpi=200)
plt.gca().set_yscale('log')
plt.xlabel('level')
plt.plot(range(1,24),abs(df.loc[1]-2),label='1.0')
plt.plot(range(1,24),abs(df.loc[0]-ye[0]),label='x^3-x^2')
plt.plot(range(1,24),abs(df.loc[2]-ye2[0]),label='1+(sin(x)+cos(x))/e^x')
plt.legend()
plt.savefig("regular.png")
plt.show()
